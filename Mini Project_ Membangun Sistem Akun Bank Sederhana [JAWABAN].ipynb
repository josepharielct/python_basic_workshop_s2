# %% [markdown]
# # Project: Membangun Sistem Akun Bank Sederhana
#  Pada sesi praktikal kali ini, teman-teman akan membangun sebuah sistem akun bank sederhana menggunakan konsep-konsep yang telah dipelajari selama 2 sesi ini.
# <br><br>
# Sistem bank yang akan dibuat pada sesi ini akan memiliki kemampuan untuk deposit uang, penarikan uang, dan menunjukkan jumlah uang yang ada di sebuah rekening.
# <br>
# ### Selamat Mengerjakan!

# %% [markdown]
# ## 1.1 Membuat Rekening Bank
#
# Hal pertama yang perlu kita buat adalah informasi-informasi yang terdapat pada sebuah akun. Informasi-informasi tersebut adalah:
# 1.   Nama Pemilik
# 2.   Nomor Rekening
# 3.   Saldo rekening
#
# Mari kita membuat 3 variabel dengan nama variabel: `nama_pemilik`,`nomor_rekening`,`saldo`
# <br><br>
# Sebagai contoh, berikut adalah informasi akun dari sebuah nasabah bank anda. Simpanlah informasi ini dalam ketiga variabel tersebut
#
# 1.   Nama nasabah adalah Joko
# 2.   Nomor rekening beliau 123456
# 3.   Saldo beliau sejumlah 1000000

# %%
#Tulis Kode Disini
nama_pemilik = 'Joko'
nomor_rekening = '123456'
saldo = 1000000

# %% [markdown]
# ## 1.2 Menampilkan Saldo Rekening
#
# Tampilkan saldo yang terdapat pada rekening di atas.
# <br><br>
#
# **Tampilkan kedua baris berikut**: <br>
# [baris pertama] Jumlah Saldo:
#  <br> [baris kedua] 1000000
#
# <br>
#
# **Challenge: Tampilkan informasi tersebut dalam 1 baris** <br>
# [Contoh Tampilan] Jumlah Saldo: 1000000
#
# Hint: Untuk melakukan aksi print dengan gabungan `string` dan `variabel`, pisahkan kedua hal tersebut dengan dengan tanda koma.

# %%
#Tulis Kode Disini 
print('Jumlah Saldo:')
print(saldo)
# Out:
# Jumlah Saldo:
# 1000000

# %%
#Kode Challenge
print('Jumlah Saldo:',saldo)
# Out:
# Jumlah Saldo: 1000000

# %% [markdown]
# Sekarang buatlah fungsi bernama `cek_saldo` yang menerima input berupa saldo (yang direpresentasikan dengan nama `uang`) dan memiliki output berupa tampilan di atas.
# <br><br>
# Setelah dibuat, tampilkan kembali saldo Joko menggunakan fungsi tersebut.

# %%
#Tulis Kode Disini 
def cek_saldo(uang):
  print('Jumlah Saldo:',uang)
cek_saldo(saldo)
# Out:
# Jumlah Saldo: 1000000

# %% [markdown]
# ## 1.3 Deposit dan Penarikan Uang
#
# Sebuah sistem bank tentu saja perlu memiliki kemampuan untuk deposit dan menarik uang. Simulasikan kedua hal tersebut dengan 2 operator yang telah dipelajari di sesi 1 dan lakukan study case ini.
#
# 1. Joko menarik 500000 dari akun banknya
# 2. Joko mendeposit 200000 ke akun banknya
# <br>
#
# Tampilkan jumlah saldo setiap kali sebuah aksi dilakukan! (Gunakanlah fungsi yang telah dibuat di bagian sebelumnya)
# <br>
# <br>
# Jangan lupa untuk mengupdate variabel `saldo` setiap kali melakukan aksi deposit dan penarikan uang.

# %%
#Tulis Kode untuk aksi 1 disini
saldo = saldo - 500000
cek_saldo(saldo)
# Out:
# Jumlah Saldo: 500000

# %%
#Tulis Kode untuk aksi 2 disini
saldo = saldo + 200000
cek_saldo(saldo)
# Out:
# Jumlah Saldo: 700000

# %% [markdown]
# Sekarang, buatlah 2 fungsi bernama `deposit` dan `penarikan` yang memiliki 2 input yaitu:
#
# 1.   Saldo saat ini (yang direpresentasikan dengan nama parameter `uang`)
# 2.   Jumlah yang ingin di deposit/ditarik (yang direpresentasikan dengan nama parameter `jumlah`)
#
# Program akan mengoutput:
# 1.   Jumlah yang telah dideposit/ditarik
#      - Contoh Tampilan Output: 50000 telah dideposit
# 2.   Jumlah saldo setelah aksi dilakukan
#      - Gunakanlah fungsi yang telah dibuat sebelumnya
#
# ### Note:
# - Jangan lupa untuk menyimpan hasil output di variabel `saldo` kembali.
#
#
#  **Hint**: Untuk menyimpan output dari sebuah fungsi, apakah digunakan `print()` atau `return`?

# %%
#Tulis kode untuk fungsi deposit dibawah ini
def deposit(uang,jumlah):
  uang = uang + jumlah
  print(jumlah, 'rupiah telah dideposit')
  cek_saldo(uang)
  return uang

# %%
#Tulis kode untuk fungsi penarikan dibawah ini
def penarikan(uang,jumlah):
  uang = uang - jumlah
  print(jumlah, 'rupiah telah ditarik')
  cek_saldo(uang)
  return uang

# %% [markdown]
# Setelah membuat kedua fungsi diatas, ujilah kedua fungsi tersebut dengan aksi-aksi berikut.
#
# 1.   Joko mendeposit 100000
# 2.   Joko menarik 50000
# 3.   Joko menarik 9999999
#
# ### Note:
# - Jangan lupa untuk menyimpan hasil output di variabel `saldo` kembali.

# %%
#Tulis Kode Dibawah
saldo = deposit(saldo,100000)
saldo = penarikan(saldo,50000)
saldo = penarikan(saldo,9999999)
# Out:
# 100000 rupiah telah dideposit
# Jumlah Saldo: 800000
# 50000 rupiah telah ditarik
# Jumlah Saldo: 750000
# 9999999 rupiah telah ditarik
# Jumlah Saldo: -9249999

# %% [markdown]
# Sebuah masalah telah terjadi, Joko telah menarik uang lebih banyak dari yang ia miliki di rekeningnya. Hal ini tidak boleh terjadi, oleh karena itu, ubahlah fungsi `penarikan()` yang telah dibuat diatas untuk menghindari hal tersebut menjadi sebagai berikut:
# - Apabila jumlah penarikan melebihi jumlah saldo saat ini, jangan lakukan penarikan. Sebagai gantinya, tampilkan kalimat berikut:
#      - Dana tidak cukup.
# <br><br>
#
# Sebelumnya, saldo pada rekening Joko telah kami kembalikan kembali menjadi saldonya sebelum aksi penarikan ilegal itu dilakukan.
#
# **Hint**
# - Gunakanlah materi Control Flow yang telah diajar di sesi 1

# %%
saldo = 750000
def penarikan(uang,jumlah):
#Tulis kode disini
  if jumlah > uang:
    print('Dana tidak cukup')
    return uang
  else:
    uang = uang - jumlah
    print(jumlah, 'rupiah telah ditarik')
    cek_saldo(uang)
    return uang

# %% [markdown]
# Untuk menguji apakah kode telah sesuai, lakukan kembali aksi penarikan sejumlah 9999999

# %%
#Tulis Kode Disini
saldo = penarikan(saldo, 9999999)
# Out:
# Dana tidak cukup

# %% [markdown]
# # 1.4 Menggabungkan semuanya
# Setelah membuat fungsi-fungsi tersebut, mari kita gabungkan bagian 1.1 sampai 1.3 menjadi satu kelas untuk menyelesaikan projek kita hari ini.
# <br><br>
# Berilah nama `sistem_bank` pada kelas yang kita buat.
# <br><br>
# Kelas ini memiliki 3 attribute yaitu
# 1.  nama_pemilik
# 2.  nomor_rekening
# 3.  saldo
# <br>
#
# Kelas ini memiliki 4 metode (5 apabila `__init__` dihitung juga) yaitu:
# 1.   deposit()
# 2.   penarikan()
# 3.   cek_saldo()
# 4.   tampilan_info()
#    - Metode tampilan info akan menampilkan nomor_rekening, nama_pemilik dan saldo.
#    Contoh tampilan output untuk nasabah Joko:<br> `Nomor rekening: 123456 , Nama pemilik: Joko , Saldo: 100000`
#
# <br>
#
# Untuk metode selain `tampilan_info()`, gunakanlah fungsi-fungsi yang telah dibuat dan modifikasi fungsinya agar dapat berjalan dengan baik di dalam kelas ini.
# <br><br>
# Setalah kelas telah dibuat, buatlah sebuah object dengan nama account1 yang mengisi detail akun milik Joko yang telah dibuat di bagian 1.1 dan cobalah metode-metode yang telah dibuat.

# %%
#Tulis Kode Disini
class sistem_bank:
    def __init__(self, nama_pemilik, nomor_rekening, saldo):
        self.nama_pemilik = nama_pemilik
        self.nomor_rekening = nomor_rekening
        self.saldo = saldo
        
    def deposit(self,jumlah):
      self.saldo = self.saldo + jumlah
      print(jumlah, 'rupiah telah dideposit')
      cek_saldo(self.saldo)

    def penarikan(self,jumlah):
      if jumlah > self.saldo:
        print('Dana tidak cukup')
      else:
        self.saldo = self.saldo - jumlah
        print(jumlah, 'rupiah telah ditarik')
        cek_saldo(self.saldo)

    def cek_saldo(self):
      print('Jumlah Saldo:',self.saldo)

    def tampilan_info(self):
        print('Nomor rekening:', self.nomor_rekening, ', Nama pemilik:', self.nama_pemilik,', Saldo:', self.saldo)

account1 = sistem_bank('Joko','12345',100000)
account1.deposit(500000)
account1.penarikan(200000)
account1.penarikan(100000000)
account1.cek_saldo()
account1.tampilan_info()
# Out:
# 500000 rupiah telah dideposit
# Jumlah Saldo: 600000
# 200000 rupiah telah ditarik
# Jumlah Saldo: 400000
# Dana tidak cukup
# Jumlah Saldo: 400000
# Nomor rekening: 12345 , Nama pemilik: Joko , Saldo: 400000

# %% [markdown]
# # 1.5 Challenge
#
# Saat ini sistem bank telah dibuat. Namun sayangnya saat ini program ini masih susah untuk dinavigasi oleh user yang tidak mengetahui bahasa pemrograman. Oleh karena itu, marilah kita membuat program lebih user friendly dengan melakukan hal-hal berikut: <br>
#
# 1. Pada Blok Kode dibawah berilah pesan selamat datang kepada user
# 2. Mintalah pengguna untuk memasukkan nama mereka, nomor rekening, dan saldo awal mereka.
# 3. Buatlah sebuah object dari kelas `sistem_bank` menggunakan informasi diatas.
# 4. Tanya user apa yang ingin mereka lakukan. Contoh: Deposit, Tarik Uang, Cek Saldo, Tunjukkan Informasi Akun, Keluar
# 5. Metode pada kelas `sistem_bank` akan dipanggil berdasarkan input dari user.
#     - Contoh: ketika user input `d`, maka user akan diminta untuk input kembali jumlah uang yang ingin ia deposit. Setelah itu, metode `deposit()` akan dipanggil dan jumlah tersebut akan dideposit ke rekening user.
# 6. Selama user tidak ingin keluar, kembali ke step 4.
#      - **Hint:** Gunakanlah salah satu loop yang dicover di sesi 1
# 7. Apabila user ingin keluar, tampilan pesan terima kasih.

# %%
#Tulis Kode Disini
#Asumsi semua input valid (saldo dan jumlah deposit/penarikan berupa angka)
print('Selamat Datang dalam Sistem Bank Saya')
nama = input('Masukkan Nama Anda: ')
norek = input('Masukkan Nomor Rekening Anda: ')
saldo = input('Masukkan Saldo: ')
akun = sistem_bank(nama,norek,int(saldo))
while True:
  command = input("\nKetik 'd' untuk melakukan deposit, 'p' untuk melakukan penarikan, \n'c' untuk cek saldo, 't' untuk menampilkan info, 'e' untuk keluar: ")
  print('\n')
  if command == 'd':
    jumlah = input('Ketik jumlah uang yang ingin dideposit: ')
    akun.deposit(int(jumlah))
  elif command == 'p':
    jumlah = input('Ketik jumlah uang yang ingin ditarik: ')
    akun.penarikan(int(jumlah))
  elif command == 'c':
    akun.cek_saldo()
  elif command == 't':
    akun.tampilan_info()
  elif command == 'e':
    print('Terima Kasih')
    break
  else:
    print('Input tidak valid')
# Out:
# Selamat Datang dalam Sistem Bank Saya
# Masukkan Nama Anda: Joko
# Masukkan Nomor Rekening Anda: 1298538
# Masukkan Saldo: 12897235
#
# Ketik 'd' untuk melakukan deposit, 'p' untuk melakukan penarikan,
# 'c' untuk cek saldo, 't' untuk menampilkan info, 'e' untuk keluar: d
#
#
# Ketik jumlah uang yang ingin dideposit: 2391483
# 2391483 rupiah telah dideposit
# Jumlah Saldo: 15288718
#
# Ketik 'd' untuk melakukan deposit, 'p' untuk melakukan penarikan,
# 'c' untuk cek saldo, 't' untuk menampilkan info, 'e' untuk keluar: p
#
#
# Ketik jumlah uang yang ingin ditarik: 9999999999999999999999
# Dana tidak cukup
#
# Ketik 'd' untuk melakukan deposit, 'p' untuk melakukan penarikan,
# 'c' untuk cek saldo, 't' untuk menampilkan info, 'e' untuk keluar: p
#
#
# Ketik jumlah uang yang ingin ditarik: 748043
# 748043 rupiah telah ditarik
# Jumlah Saldo: 14540675
#
# Ketik 'd' untuk melakukan deposit, 'p' untuk melakukan penarikan,
# ...

# %%
1
